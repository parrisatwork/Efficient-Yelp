# %% [markdown]
# # Efficient Yelp API Calls (Core)
#
# ### For this assignment, you will be working with the Yelp API.
#
# ### As before, you will use the Yelp API to search your favorite city for a cuisine type of your choice.
#
# ### Extract all of the results from your search and compile them into one dataframe using a for loop as shown in the lesson "Code for Efficient API Extraction"

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json, math, time
from yelpapi import YelpAPI
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in c:\users\parri_nqdmzn3\anaconda3\envs\dojo-env\lib\site-packages (2.5.0)
# Requirement already satisfied: requests in c:\users\parri_nqdmzn3\anaconda3\envs\dojo-env\lib\site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\parri_nqdmzn3\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parri_nqdmzn3\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\parri_nqdmzn3\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parri_nqdmzn3\anaconda3\envs\dojo-env\lib\site-packages (from requests->yelpapi) (2022.9.24)
# Requirement already satisfied: tqdm in c:\users\parri_nqdmzn3\anaconda3\envs\dojo-env\lib\site-packages (4.64.1)
# Requirement already satisfied: colorama in c:\users\parri_nqdmzn3\anaconda3\envs\dojo-env\lib\site-packages (from tqdm) (0.4.5)

# %%
import json
with open('/Users/parri_nqdmzn3/.secret/yelp_api.json') as f:
    login = json.load(f)
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
from yelpapi import YelpAPI
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)
yelp_api

# %% [markdown]
# ### Yelp Search

# %%
location = 'San Antonio, Texas 78253'
term = 'chinese'

# %%
location.split(',')[0]
# Out:
# 'San Antonio'

# %%
folder = 'Data/'

os.makedirs(folder, exist_ok=True)

JSON_FILE = folder+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/San Antonio-chinese.json'

# %% [markdown]
# ### Confirming Files

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:    
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON folder name is not empty:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/San Antonio-chinese.json not found. Saving empty list to file.

# %%
os.path.isfile(JSON_FILE)
# Out:
# True

# %% [markdown]
# ### Load JSON

# %%
results = yelp_api.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['total']
# Out:
# 88

# %%
results['region']
# Out:
# {'center': {'longitude': -98.79592895507812, 'latitude': 29.470648213030426}}

# %%
results['businesses']
# Out:
# [{'id': 'wCURMa_PGJ-pDCJYzdhDyg',
#   'alias': 'rice-and-spicy-san-antonio',
#   'name': 'Rice & Spicy',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WjakyvEBVD860ADRz2hH8g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/rice-and-spicy-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 71,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.5271, 'longitude': -98.72229},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '11590 Galm Rd',
#    'address2': 'Ste 108',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78254',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['11590 Galm Rd', 'Ste 108', 'San Antonio, TX 78254']},
#   'phone': '+12109995112',
#   'display_phone': '(210) 999-5112',
#   'distance': 9715.633559353028},
#  {'id': 'zA74m8K0IYQMT4FfthcUGw',
#   'alias': 'sichuan-house-san-antonio',
#   'name': 'Sichuan House',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7xU23UMInFyem7pIsHLgyw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sichuan-house-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 1014,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.471805, 'longitude': -98.623466},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3505 Wurzbach Rd',
#    'address2': 'Ste 103',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78238',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['3505 Wurzbach Rd',
#     'Ste 103',
#     'San Antonio, TX 78238']},
#   'phone': '+12105099999',
#   'display_phone': '(210) 509-9999',
#   'distance': 16690.583465327836},
#  {'id': 'ktyeFjGTfvsNimBxNswvfw',
#   'alias': 'tjin-china-diner-san-antonio',
#   'name': 'Tjin China Diner',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/JypG-0k-2UZgkiM3KCjuYg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tjin-china-diner-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 302,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.437046568496463,
#    'longitude': -98.6474904677673},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '119 SW Lp 410',
#    'address2': 'Ste 103',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78245',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['119 SW Lp 410', 'Ste 103', 'San Antonio, TX 78245']},
#   'phone': '+12109982078',
#   'display_phone': '(210) 998-2078',
#   'distance': 14849.996793127515},
#  {'id': 'yEbVfGVqp_yuLrCP02qkaQ',
#   'alias': 'house-of-china-san-antonio',
#   'name': 'House of China',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A_3IiytvrVCIQWyHG1iZMw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/house-of-china-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 191,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 29.48848, 'longitude': -98.706555},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '5630 W Loop 1604 N',
#    'address2': 'Ste 102',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78251',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5630 W Loop 1604 N',
#     'Ste 102',
#     'San Antonio, TX 78251']},
#   'phone': '+12105097888',
#   'display_phone': '(210) 509-7888',
#   'distance': 8875.582512749916},
#  {'id': 'tQxJmTYnIlPqeBD7ESWMqA',
#   'alias': 'lin-s-express-potranco-san-antonio',
#   'name': 'Lin’s Express Potranco',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RufqZNNmyJ6HP3L7-VNlQg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lin-s-express-potranco-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 60,
#   'categories': [{'alias': 'panasian', 'title': 'Pan Asian'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 29.429686032622598, 'longitude': -98.7412969},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '12370 Fm 1957',
#    'address2': 'Ste 210',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78253',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['12370 Fm 1957', 'Ste 210', 'San Antonio, TX 78253']},
#   'phone': '+12104657791',
#   'display_phone': '(210) 465-7791',
#   'distance': 6980.573663376544},
#  {'id': 'ZtBR3SH_XRwGiYvQdZOMqw',
#   'alias': 'asia-restaurant-san-antonio-2',
#   'name': 'Asia Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/60u_DpU9BKpLBSbQC80Ayw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/asia-restaurant-san-antonio-2?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 115,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.4659614562988,
#    'longitude': -98.6455688476562},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '8035 Culebra Rd',
#    'address2': 'Ste 107',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78251',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8035 Culebra Rd', 'Ste 107', 'San Antonio, TX 78251']},
#   'phone': '+12106807323',
#   'display_phone': '(210) 680-7323',
#   'distance': 14581.40012525322},
#  {'id': '2SCe_RBPuAJauOSWedSJqA',
#   'alias': 'lins-express-san-antonio',
#   'name': 'Lins Express',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UOJHRDU1U7JzFO0uObhfvA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lins-express-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 55,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.484974, 'longitude': -98.72756},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '11841 Alamo Ranch Pkwy',
#    'address2': 'Ste 114',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78253',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['11841 Alamo Ranch Pkwy',
#     'Ste 114',
#     'San Antonio, TX 78253']},
#   'phone': '+12103621812',
#   'display_phone': '(210) 362-1812',
#   'distance': 6807.139512580313},
#  {'id': 'hKSwFoVXwr9SpeiH6Na29A',
#   'alias': 'tiger-s-chinese-cuisine-san-antonio',
#   'name': 'Tiger’s Chinese Cuisine',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/onJixHJdLYGhMQjxaZ0jFQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tiger-s-chinese-cuisine-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 113,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.56257943164515,
#    'longitude': -98.59308316705979},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '12730 W I-10 Frontage Rd',
#    'address2': 'Ste 312',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78230',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['12730 W I-10 Frontage Rd',
#     'Ste 312',
#     'San Antonio, TX 78230']},
#   'phone': '+12105385080',
#   'display_phone': '(210) 538-5080',
#   'distance': 22130.36145408426},
#  {'id': 'BspvwcGxdFJz1aa72Z72gQ',
#   'alias': 'royal-inn-oriental-cuisine-san-antonio',
#   'name': 'Royal Inn Oriental Cuisine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7ye9nih-j4ep_KLDW2mykw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/royal-inn-oriental-cuisine-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 252,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.5160312652588,
#    'longitude': -98.5941314697266},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '5440 Babcock Rd',
#    'address2': 'Ste 150',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78240',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5440 Babcock Rd', 'Ste 150', 'San Antonio, TX 78240']},
#   'phone': '+12106910602',
#   'display_phone': '(210) 691-0602',
#   'distance': 20121.3491578562},
#  {'id': 't-5TU4Jn4JksVz09OKf_Qw',
#   'alias': 'oolong-chinese-bistro-helotes',
#   'name': 'Oolong Chinese Bistro',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/nx75NwvlefoBEes544VtCQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/oolong-chinese-bistro-helotes?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 216,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.55851, 'longitude': -98.67577},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '12411 Bandera Rd',
#    'address2': 'Ste 103',
#    'address3': '',
#    'city': 'Helotes',
#    'zip_code': '78023',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['12411 Bandera Rd', 'Ste 103', 'Helotes, TX 78023']},
#   'phone': '+12106959755',
#   'display_phone': '(210) 695-9755',
#   'distance': 15172.29043513387},
#  {'id': 'oCCpQTfC0iZG-PZUFWTWlw',
#   'alias': 'artea-culebra-commons-san-antonio',
#   'name': 'Artea - Culebra Commons',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fyI4MiCR6JOE2XwpjwasQg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/artea-culebra-commons-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 127,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 29.502815891590274,
#    'longitude': -98.69960125000753},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '7010 W Loop 1604 N',
#    'address2': 'Ste 201',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78254',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['7010 W Loop 1604 N',
#     'Ste 201',
#     'San Antonio, TX 78254']},
#   'phone': '+12108883820',
#   'display_phone': '(210) 888-3820',
#   'distance': 9986.28374958213},
#  {'id': '86WWY2fqjhu6aH54thfbBw',
#   'alias': 'wok-inn-asian-cafe-san-antonio-4',
#   'name': 'Wok Inn Asian Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TaClOGTozUf1KX7lNLa5Wg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wok-inn-asian-cafe-san-antonio-4?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 129,
#   'categories': [{'alias': 'panasian', 'title': 'Pan Asian'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 29.497259500176014,
#    'longitude': -98.70842908877945},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '10919 Culebra Rd',
#    'address2': 'Ste 170',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78253',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['10919 Culebra Rd',
#     'Ste 170',
#     'San Antonio, TX 78253']},
#   'phone': '+12106821688',
#   'display_phone': '(210) 682-1688',
#   'distance': 8971.522503050472},
#  {'id': 'h8RUrgghqoS1sn5ADC5gbg',
#   'alias': 'sukhothai-thai-restaurant-express-3-san-antonio-2',
#   'name': 'Sukhothai Thai Restaurant Express 3',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ySjrc8A-1MWs1IbMliBE1w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sukhothai-thai-restaurant-express-3-san-antonio-2?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 4,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 29.485357, 'longitude': -98.724984},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '11720 Alamo Rnch Pkwy',
#    'address2': 'Ste 210',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78253',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['11720 Alamo Rnch Pkwy',
#     'Ste 210',
#     'San Antonio, TX 78253']},
#   'phone': '+12102815754',
#   'display_phone': '(210) 281-5754',
#   'distance': 7056.760604793281},
#  {'id': '6wjVlVZpyI_4pvtwGVxvVw',
#   'alias': 'yum-thai-restaurant-san-antonio',
#   'name': 'Yum Thai Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/__Nbf6XT1P5xuLPvKoylKw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yum-thai-restaurant-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 374,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.49131067548097,
#    'longitude': -98.7088356133807},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '5511 N W Lp 1604',
#    'address2': 'Ste 115',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78253',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['5511 N W Lp 1604',
#     'Ste 115',
#     'San Antonio, TX 78253']},
#   'phone': '+12105090000',
#   'display_phone': '(210) 509-0000',
#   'distance': 8737.864496502709},
#  {'id': 'rgVC998osY5kDjgBmGS1CA',
#   'alias': 'lins-express-san-antonio-2',
#   'name': 'Lins Express',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kxLgF4j97_iVLOxn45305A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lins-express-san-antonio-2?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 24,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'food', 'title': 'Food'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.50431786207835,
#    'longitude': -98.72976452798454},
#   'transactions': ['delivery', 'pickup'],
#   'location': {'address1': '11911 Culebra Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78253',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['11911 Culebra Rd', 'San Antonio, TX 78253']},
#   'phone': '+12105602033',
#   'display_phone': '(210) 560-2033',
#   'distance': 7418.184889702309},
#  {'id': 'uvhk_f7eFC85IkjesC3S-w',
#   'alias': 'singapore-chinese-and-indochina-restaurant-san-antonio-5',
#   'name': 'Singapore Chinese & Indochina Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XPB4ngOzaUUMoLE0RZLBUw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/singapore-chinese-and-indochina-restaurant-san-antonio-5?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 244,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.576857628915484,
#    'longitude': -98.6261407233134},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '7114 Utsa Blvd',
#    'address2': 'Ste 105',
#    'address3': None,
#    'city': 'San Antonio',
#    'zip_code': '78249',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['7114 Utsa Blvd', 'Ste 105', 'San Antonio, TX 78249']},
#   'phone': '+12108999181',
#   'display_phone': '(210) 899-9181',
#   'distance': 20232.556479537187},
#  {'id': 'xtGLItkfk0MFhwu0Riipvw',
#   'alias': 'asia-kitchen-san-antonio',
#   'name': 'Asia Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y4WPDsaNqjUmUw31-wXa-g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/asia-kitchen-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 301,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 29.4130724597875,
#    'longitude': -98.6511658809509},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1739 SW Loop 410',
#    'address2': 'Ste 201-204',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78227',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1739 SW Loop 410',
#     'Ste 201-204',
#     'San Antonio, TX 78227']},
#   'phone': '+12106730662',
#   'display_phone': '(210) 673-0662',
#   'distance': 15410.818118989815},
#  {'id': '7gPxqcNvJNbBQNEEbE_NPA',
#   'alias': 'thai-wok-san-antonio',
#   'name': 'Thai Wok',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PZUKR1a11o0pxXrwH3mbYQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/thai-wok-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 34,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 29.47882417047466,
#    'longitude': -98.66378479256119},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '8923 Culebra Rd',
#    'address2': 'Ste 107',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78251',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8923 Culebra Rd', 'Ste 107', 'San Antonio, TX 78251']},
#   'phone': '+12109995671',
#   'display_phone': '(210) 999-5671',
#   'distance': 12824.237367900578},
#  {'id': 'xPflGR2n3ddeb5-1cEfoCA',
#   'alias': 'happy-guy-chinese-cuisine-san-antonio',
#   'name': 'Happy Guy Chinese Cuisine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Vq1ZVu8B71Hu-cyCjcqAvg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/happy-guy-chinese-cuisine-san-antonio?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 163,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 29.47015, 'longitude': -98.64908},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '8373 Culebra Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78251',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['8373 Culebra Rd', 'San Antonio, TX 78251']},
#   'phone': '+12105201728',
#   'display_phone': '(210) 520-1728',
#   'distance': 14230.639932010397},
#  {'id': 'CJEHtQrzkeqTqiWwAvWmIA',
#   'alias': 'golden-wok-san-antonio-5',
#   'name': 'Golden Wok',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3EKG-JKAyeH6LZxyoPddRg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/golden-wok-san-antonio-5?adjust_creative=BiiAqVQ4IB4FQ6304SqKwg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=BiiAqVQ4IB4FQ6304SqKwg',
#   'review_count': 263,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 29.4207226131529,
#    'longitude': -98.6487636850798},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1410 SW Loop 410',
#    'address2': '',
#    'address3': '',
#    'city': 'San Antonio',
#    'zip_code': '78227',
#    'country': 'US',
#    'state': 'TX',
#    'display_address': ['1410 SW Loop 410', 'San Antonio, TX 78227']},
#   'phone': '+12106742577',
#   'display_phone': '(210) 674-2577',
#   'distance': 15293.310784973215}]

# %%
pd.DataFrame(results['businesses'])
# Out:
#                         id                                              alias  \
# 0   wCURMa_PGJ-pDCJYzdhDyg                         rice-and-spicy-san-antonio
# 1   zA74m8K0IYQMT4FfthcUGw                          sichuan-house-san-antonio
# 2   ktyeFjGTfvsNimBxNswvfw                       tjin-china-diner-san-antonio
# 3   yEbVfGVqp_yuLrCP02qkaQ                         house-of-china-san-antonio
# 4   tQxJmTYnIlPqeBD7ESWMqA                 lin-s-express-potranco-san-antonio
# 5   ZtBR3SH_XRwGiYvQdZOMqw                      asia-restaurant-san-antonio-2
# 6   2SCe_RBPuAJauOSWedSJqA                           lins-express-san-antonio
# 7   hKSwFoVXwr9SpeiH6Na29A                tiger-s-chinese-cuisine-san-antonio
# 8   BspvwcGxdFJz1aa72Z72gQ             royal-inn-oriental-cuisine-san-antonio
# 9   t-5TU4Jn4JksVz09OKf_Qw                      oolong-chinese-bistro-helotes
# 10  oCCpQTfC0iZG-PZUFWTWlw                  artea-culebra-commons-san-antonio
# 11  86WWY2fqjhu6aH54thfbBw                   wok-inn-asian-cafe-san-antonio-4
# 12  h8RUrgghqoS1sn5ADC5gbg  sukhothai-thai-restaurant-express-3-san-antonio-2
# 13  6wjVlVZpyI_4pvtwGVxvVw                    yum-thai-restaurant-san-antonio
# 14  rgVC998osY5kDjgBmGS1CA                         lins-express-san-antonio-2
# 15  uvhk_f7eFC85IkjesC3S-w  singapore-chinese-and-indochina-restaurant-san...
# 16  xtGLItkfk0MFhwu0Riipvw                           asia-kitchen-san-antonio
# 17  7gPxqcNvJNbBQNEEbE_NPA                               thai-wok-san-antonio
# 18  xPflGR2n3ddeb5-1cEfoCA              happy-guy-chinese-cuisine-san-antonio
# 19  CJEHtQrzkeqTqiWwAvWmIA                           golden-wok-san-antonio-5
#
#                                         name  \
# 0                               Rice & Spicy
# 1                              Sichuan House
# 2                           Tjin China Diner
# 3                             House of China
# 4                     Lin’s Express Potranco
# 5                            Asia Restaurant
# 6                               Lins Express
# 7                    Tiger’s Chinese Cuisine
# 8                 Royal Inn Oriental Cuisine
# 9                      Oolong Chinese Bistro
# 10                   Artea - Culebra Commons
# 11                        Wok Inn Asian Cafe
# 12       Sukhothai Thai Restaurant Express 3
# 13                       Yum Thai Restaurant
# 14                              Lins Express
# 15  Singapore Chinese & Indochina Restaurant
# 16                              Asia Kitchen
# 17                                  Thai Wok
# 18                 Happy Guy Chinese Cuisine
# 19                                Golden Wok
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/Wjakyv...      False
# 1   https://s3-media4.fl.yelpcdn.com/bphoto/7xU23U...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/JypG-0...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/A_3Iiy...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/RufqZN...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/60u_Dp...      False
# 6   https://s3-media3.fl.yelpcdn.com/bphoto/UOJHRD...      False
# 7   https://s3-media1.fl.yelpcdn.com/bphoto/onJixH...      False
# 8   https://s3-media2.fl.yelpcdn.com/bphoto/7ye9ni...      False
# 9   https://s3-media4.fl.yelpcdn.com/bphoto/nx75Nw...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/fyI4Mi...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/TaClOG...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/ySjrc8...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/__Nbf6...      False
# 14  https://s3-media1.fl.yelpcdn.com/bphoto/kxLgF4...      False
# 15  https://s3-media2.fl.yelpcdn.com/bphoto/XPB4ng...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/y4WPDs...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/PZUKR1...      False
# 18  https://s3-media2.fl.yelpcdn.com/bphoto/Vq1ZVu...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/3EKG-J...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/rice-and-spicy-san-an...            71
# 1   https://www.yelp.com/biz/sichuan-house-san-ant...          1014
# 2   https://www.yelp.com/biz/tjin-china-diner-san-...           302
# 3   https://www.yelp.com/biz/house-of-china-san-an...           191
# 4   https://www.yelp.com/biz/lin-s-express-potranc...            60
# 5   https://www.yelp.com/biz/asia-restaurant-san-a...           115
# 6   https://www.yelp.com/biz/lins-express-san-anto...            55
# 7   https://www.yelp.com/biz/tiger-s-chinese-cuisi...           113
# 8   https://www.yelp.com/biz/royal-inn-oriental-cu...           252
# 9   https://www.yelp.com/biz/oolong-chinese-bistro...           216
# 10  https://www.yelp.com/biz/artea-culebra-commons...           127
# 11  https://www.yelp.com/biz/wok-inn-asian-cafe-sa...           129
# 12  https://www.yelp.com/biz/sukhothai-thai-restau...             4
# 13  https://www.yelp.com/biz/yum-thai-restaurant-s...           374
# 14  https://www.yelp.com/biz/lins-express-san-anto...            24
# 15  https://www.yelp.com/biz/singapore-chinese-and...           244
# 16  https://www.yelp.com/biz/asia-kitchen-san-anto...           301
# 17  https://www.yelp.com/biz/thai-wok-san-antonio?...            34
# 18  https://www.yelp.com/biz/happy-guy-chinese-cui...           163
# 19  https://www.yelp.com/biz/golden-wok-san-antoni...           263
#
#                                            categories  rating  \
# 0   [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     4.5
# 1   [{'alias': 'szechuan', 'title': 'Szechuan'}, {...     4.5
# 2          [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 3   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     2.5
# 4       [{'alias': 'panasian', 'title': 'Pan Asian'}]     3.0
# 5          [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 6   [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     3.5
# 7        [{'alias': 'szechuan', 'title': 'Szechuan'}]     4.0
# 8   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
# 9          [{'alias': 'chinese', 'title': 'Chinese'}]     3.5
# 10  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
# 11      [{'alias': 'panasian', 'title': 'Pan Asian'}]     2.0
# 12  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     5.0
# 13               [{'alias': 'thai', 'title': 'Thai'}]     3.5
# 14  [{'alias': 'hotdogs', 'title': 'Fast Food'}, {...     4.0
# 15  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     3.5
# 16  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
# 17  [{'alias': 'thai', 'title': 'Thai'}, {'alias':...     5.0
# 18         [{'alias': 'chinese', 'title': 'Chinese'}]     3.5
# 19         [{'alias': 'chinese', 'title': 'Chinese'}]     3.0
#
#                                           coordinates        transactions  \
# 0       {'latitude': 29.5271, 'longitude': -98.72229}  [delivery, pickup]
# 1    {'latitude': 29.471805, 'longitude': -98.623466}  [pickup, delivery]
# 2   {'latitude': 29.437046568496463, 'longitude': ...          [delivery]
# 3     {'latitude': 29.48848, 'longitude': -98.706555}  [delivery, pickup]
# 4   {'latitude': 29.429686032622598, 'longitude': ...          [delivery]
# 5   {'latitude': 29.4659614562988, 'longitude': -9...  [pickup, delivery]
# 6     {'latitude': 29.484974, 'longitude': -98.72756}  [delivery, pickup]
# 7   {'latitude': 29.56257943164515, 'longitude': -...  [delivery, pickup]
# 8   {'latitude': 29.5160312652588, 'longitude': -9...  [delivery, pickup]
# 9      {'latitude': 29.55851, 'longitude': -98.67577}          [delivery]
# 10  {'latitude': 29.502815891590274, 'longitude': ...  [delivery, pickup]
# 11  {'latitude': 29.497259500176014, 'longitude': ...          [delivery]
# 12   {'latitude': 29.485357, 'longitude': -98.724984}  [delivery, pickup]
# 13  {'latitude': 29.49131067548097, 'longitude': -...  [delivery, pickup]
# 14  {'latitude': 29.50431786207835, 'longitude': -...  [delivery, pickup]
# 15  {'latitude': 29.576857628915484, 'longitude': ...  [delivery, pickup]
# 16  {'latitude': 29.4130724597875, 'longitude': -9...          [delivery]
# 17  {'latitude': 29.47882417047466, 'longitude': -...  [pickup, delivery]
# 18     {'latitude': 29.47015, 'longitude': -98.64908}          [delivery]
# 19  {'latitude': 29.4207226131529, 'longitude': -9...          [delivery]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '11590 Galm Rd', 'address2': 'Ste...  +12109995112
# 1     $$  {'address1': '3505 Wurzbach Rd', 'address2': '...  +12105099999
# 2     $$  {'address1': '119 SW Lp 410', 'address2': 'Ste...  +12109982078
# 3      $  {'address1': '5630 W Loop 1604 N', 'address2':...  +12105097888
# 4     $$  {'address1': '12370 Fm 1957', 'address2': 'Ste...  +12104657791
# 5      $  {'address1': '8035 Culebra Rd', 'address2': 'S...  +12106807323
# 6     $$  {'address1': '11841 Alamo Ranch Pkwy', 'addres...  +12103621812
# 7     $$  {'address1': '12730 W I-10 Frontage Rd', 'addr...  +12105385080
# 8      $  {'address1': '5440 Babcock Rd', 'address2': 'S...  +12106910602
# 9     $$  {'address1': '12411 Bandera Rd', 'address2': '...  +12106959755
# 10   NaN  {'address1': '7010 W Loop 1604 N', 'address2':...  +12108883820
# 11     $  {'address1': '10919 Culebra Rd', 'address2': '...  +12106821688
# 12   NaN  {'address1': '11720 Alamo Rnch Pkwy', 'address...  +12102815754
# 13    $$  {'address1': '5511 N W Lp 1604', 'address2': '...  +12105090000
# 14   NaN  {'address1': '11911 Culebra Rd', 'address2': '...  +12105602033
# 15    $$  {'address1': '7114 Utsa Blvd', 'address2': 'St...  +12108999181
# 16     $  {'address1': '1739 SW Loop 410', 'address2': '...  +12106730662
# 17   NaN  {'address1': '8923 Culebra Rd', 'address2': 'S...  +12109995671
# 18     $  {'address1': '8373 Culebra Rd', 'address2': ''...  +12105201728
# 19    $$  {'address1': '1410 SW Loop 410', 'address2': '...  +12106742577
#
#      display_phone      distance
# 0   (210) 999-5112   9715.633559
# 1   (210) 509-9999  16690.583465
# 2   (210) 998-2078  14849.996793
# 3   (210) 509-7888   8875.582513
# 4   (210) 465-7791   6980.573663
# 5   (210) 680-7323  14581.400125
# 6   (210) 362-1812   6807.139513
# 7   (210) 538-5080  22130.361454
# 8   (210) 691-0602  20121.349158
# 9   (210) 695-9755  15172.290435
# 10  (210) 888-3820   9986.283750
# 11  (210) 682-1688   8971.522503
# 12  (210) 281-5754   7056.760605
# 13  (210) 509-0000   8737.864497
# 14  (210) 560-2033   7418.184890
# 15  (210) 899-9181  20232.556480
# 16  (210) 673-0662  15410.818119
# 17  (210) 999-5671  12824.237368
# 18  (210) 520-1728  14230.639932
# 19  (210) 674-2577  15293.310785

# %%
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %%
(results['total'])/ results_per_page
# Out:
# 4.4

# %%
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 5

# %% [markdown]
# ## Progress Bar

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    try:
        
        time.sleep(.2)
    
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        n_results = len(previous_results)
        
        results = yelp_api.search_query(location = location, term = term,
                                   offset = n_results+1)

        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)

            
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ## Opening Final JSON file via Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                               alias  \
# 0  zA74m8K0IYQMT4FfthcUGw           sichuan-house-san-antonio
# 1  ktyeFjGTfvsNimBxNswvfw        tjin-china-diner-san-antonio
# 2  yEbVfGVqp_yuLrCP02qkaQ          house-of-china-san-antonio
# 3  tQxJmTYnIlPqeBD7ESWMqA  lin-s-express-potranco-san-antonio
# 4  ZtBR3SH_XRwGiYvQdZOMqw       asia-restaurant-san-antonio-2
#
#                      name                                          image_url  \
# 0           Sichuan House  https://s3-media4.fl.yelpcdn.com/bphoto/7xU23U...
# 1        Tjin China Diner  https://s3-media1.fl.yelpcdn.com/bphoto/JypG-0...
# 2          House of China  https://s3-media2.fl.yelpcdn.com/bphoto/A_3Iiy...
# 3  Lin’s Express Potranco  https://s3-media2.fl.yelpcdn.com/bphoto/RufqZN...
# 4         Asia Restaurant  https://s3-media2.fl.yelpcdn.com/bphoto/60u_Dp...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/sichuan-house-san-ant...          1014
# 1      False  https://www.yelp.com/biz/tjin-china-diner-san-...           302
# 2      False  https://www.yelp.com/biz/house-of-china-san-an...           191
# 3      False  https://www.yelp.com/biz/lin-s-express-potranc...            60
# 4      False  https://www.yelp.com/biz/asia-restaurant-san-a...           115
#
#                                           categories  rating  \
# 0  [{'alias': 'szechuan', 'title': 'Szechuan'}, {...     4.5
# 1         [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 2  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     2.5
# 3      [{'alias': 'panasian', 'title': 'Pan Asian'}]     3.0
# 4         [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
#
#                                          coordinates        transactions  \
# 0   {'latitude': 29.471805, 'longitude': -98.623466}  [delivery, pickup]
# 1  {'latitude': 29.437046568496463, 'longitude': ...          [delivery]
# 2    {'latitude': 29.48848, 'longitude': -98.706555}  [delivery, pickup]
# 3  {'latitude': 29.429686032622598, 'longitude': ...          [delivery]
# 4  {'latitude': 29.4659614562988, 'longitude': -9...  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '3505 Wurzbach Rd', 'address2': '...  +12105099999
# 1    $$  {'address1': '119 SW Lp 410', 'address2': 'Ste...  +12109982078
# 2     $  {'address1': '5630 W Loop 1604 N', 'address2':...  +12105097888
# 3    $$  {'address1': '12370 Fm 1957', 'address2': 'Ste...  +12104657791
# 4     $  {'address1': '8035 Culebra Rd', 'address2': 'S...  +12106807323
#
#     display_phone      distance
# 0  (210) 509-9999  16690.583465
# 1  (210) 998-2078  14849.996793
# 2  (210) 509-7888   8875.582513
# 3  (210) 465-7791   6980.573663
# 4  (210) 680-7323  14581.400125

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             87 non-null     object
#  1   alias          87 non-null     object
#  2   name           87 non-null     object
#  3   image_url      87 non-null     object
#  4   is_closed      87 non-null     bool
#  5   url            87 non-null     object
#  6   review_count   87 non-null     int64
#  7   categories     87 non-null     object
#  8   rating         87 non-null     float64
#  9   coordinates    87 non-null     object
#  10  transactions   87 non-null     object
#  11  price          67 non-null     object
#  12  location       87 non-null     object
#  13  phone          87 non-null     object
#  14  display_phone  87 non-null     object
#  15  distance       87 non-null     float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 10.4+ KB

# %%
df.duplicated(subset='id').sum()
# Out:
# 0

# %% [markdown]
# ### File Conversion

# %%
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/San Antonio-chinese.csv.gz'

# %%
df.to_csv(csv_file,compression = 'gzip', index=False)

# %% [markdown]
# ###  File sizes

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 85,643 Bytes
# CSV.GZ FILE: 12,411 Bytes
# the csv.gz is 6.900572073160905 times smaller!
